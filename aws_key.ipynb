# %%
from boto3.session import Session
import boto3

s = Session()

4Htfc8evvRNFRSZYJ7e6i5PdSXJbNlDMED549N71

client = boto3.client(
    'comprehendmedical',
    aws_access_key_id='AKIARKNYZVRLGR3RJQ4V',
    aws_secret_access_key='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',
    region_name="ca-central-1"
)
s ="ABC"
result = client.detect_entities(Text= s)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Input In [1], in <cell line: 15>()
#       8 client = boto3.client(
#       9     'comprehendmedical',
#      10     aws_access_key_id='AKIARKNYZVRLL46BFDN4',
#      11     aws_secret_access_key='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',
#      12     region_name="ca-central-1"
#      13 )
#      14 s ="ABC"
# ---> 15 result = client.detect_entities(Text= s)
#
# File /usr/local/lib/python3.8/dist-packages/botocore/client.py:357, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     354     raise TypeError(
#     355         "%s() only accepts keyword arguments." % py_operation_name)
#     356 # The "self" in this scope is referring to the BaseClient.
# --> 357 return self._make_api_call(operation_name, kwargs)
#
# ...
