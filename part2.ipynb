# %%
import pandas as pd
import numpy as np
data = pd.read_csv("/home/rsingh/lab_data/output/csv/patients.csv", nrows=5)
pd.set_option('display.max_columns', 200)

# %%
data['BIRTHDATE'] = pd.to_datetime(data['BIRTHDATE'])
data
# Out:
#                                      Id  BIRTHDATE  DEATHDATE          SSN  \
# 0  fda9193a-4ffd-b3bc-e789-92c973aee4fe 2018-12-13        NaN  999-74-9259
# 1  815a5aba-d663-3a4d-39b6-e0675923261c 2012-01-25        NaN  999-48-9088
# 2  02c6dc9a-d7bf-0e5d-5149-b8e033b146ea 2006-01-06        NaN  999-55-5935
# 3  d707860d-412a-0d9d-d253-b5fc224dc187 2008-04-07        NaN  999-69-7479
# 4  cf1b65f2-7064-7019-c78d-eea09346660f 2019-08-02        NaN  999-72-3368
#
#      DRIVERS  PASSPORT  PREFIX         FIRST            LAST  SUFFIX  MAIDEN  \
# 0        NaN       NaN     NaN  Kimberlie352  Schamberger479     NaN     NaN
# 1        NaN       NaN     NaN      Bulah832      Reinger292     NaN     NaN
# 2  S99986239       NaN     NaN       Tyra356       Miller503     NaN     NaN
# 3        NaN       NaN     NaN     Hernán834    Cervantes583     NaN     NaN
# 4        NaN       NaN     NaN      Debra128      Keebler762     NaN     NaN
#
# ...

# %%
from anonympy.pandas.utils_pandas import available_methods
from anonympy.pandas import dfAnonymizer

# %%
anonym = dfAnonymizer(data)

# %%
anonym.anonymize({'FIRST': 'categorical_resampling',
                 'BIRTHDATE':'datetime_noise'})
anonym.to_df()
# Out:
#                                      Id  BIRTHDATE  DEATHDATE          SSN  \
# 0  fda9193a-4ffd-b3bc-e789-92c973aee4fe 2018-07-15        NaN  999-74-9259
# 1  815a5aba-d663-3a4d-39b6-e0675923261c 2011-11-23        NaN  999-48-9088
# 2  02c6dc9a-d7bf-0e5d-5149-b8e033b146ea 2005-05-10        NaN  999-55-5935
# 3  d707860d-412a-0d9d-d253-b5fc224dc187 2008-11-07        NaN  999-69-7479
# 4  cf1b65f2-7064-7019-c78d-eea09346660f 2019-09-03        NaN  999-72-3368
#
#      DRIVERS  PASSPORT  PREFIX         FIRST            LAST  SUFFIX  MAIDEN  \
# 0        NaN       NaN     NaN  Kimberlie352  Schamberger479     NaN     NaN
# 1        NaN       NaN     NaN      Bulah832      Reinger292     NaN     NaN
# 2  S99986239       NaN     NaN     Hernán834       Miller503     NaN     NaN
# 3        NaN       NaN     NaN       Tyra356    Cervantes583     NaN     NaN
# 4        NaN       NaN     NaN     Hernán834      Keebler762     NaN     NaN
#
# ...
